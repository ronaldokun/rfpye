# %%
#hide   
import warnings
import gc
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
from pprint import pprint as pp
from datetime import datetime as dt
from typing import *
import rfpy
from rfpy.parser import *
from rfpy.utils import *
from rfpy.blocks import *
from rfpy.main import export_metadata
from nbdev.showdoc import *
from fastcore.xtras import Path
from fastcore.foundation import L
from fastcore.test import *
import numpy as np
import pandas as pd

# %%
#hide
# %load_ext autoreload
# %autoreload 2 
# %load_ext line_profiler

# %% [markdown]
# Caminho das pastas de entrada e saída

# %%
entrada = Path(r'C:\Users\rsilva\Downloads\entrada')
saida = Path(r'C:\Users\rsilva\Downloads\saida')

# %% [markdown]
# Função que mapeia os arquivos da pasta e retorna um lista generalizada `L`

# %%
arquivos = get_files(entrada) ;  arquivos
# Out:
# (#5) [Path('C:/Users/rsilva/Downloads/entrada/201201_T153421_OneThreadID.bin'),Path('C:/Users/rsilva/Downloads/entrada/201201_T154509_MultiplesThreadID.bin'),Path('C:/Users/rsilva/Downloads/entrada/rfeye002092_210223_T163131_MaskBroken.bin'),Path('C:/Users/rsilva/Downloads/entrada/rfeye002292_210210_T230245_MaskBroken.bin'),Path('C:/Users/rsilva/Downloads/entrada/pmec/rfeye002304_SLMA_PEAK_200828_132002.bin')]

# %%
# %%time
# %lprun -f create_base_block multi = parse_bin(arquivos[1])
# Out:
# Wall time: 3.37 s
# Timer unit: 3.52617e-07 s
#
# Total time: 2.62583 s
# File: c:\users\rsilva\code\rfpy\rfpy\blocks.py
# Function: create_base_block at line 39
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     39                                           def create_base_block(bin_block: bytes)->Tuple:
#     40                                               """
#     41                                               A block is a piece of the .bin file with a known start and end and that contains different types of information.
#     42                                               It has several fields: type, header, data and footer.
#     43                                               Each field has lengths and information defined in the documentation.
#     44                                               Receives a block from the bin file and returns a Base Block instance with the attributes
#     45                                               'thread_id', 'data_size', 'type', 'data', 'checksum'
#     46                                               """
#     47     46397      90775.0      2.0      1.2      if not isinstance(bin_block, bytes):
#     48                                                   raise TypeError(f"Expected type 'bytes', got '{type(bin_block)}' instead.")
#     49     46397    7355907.0    158.5     98.8      return BaseBlock(*L(bin_block[:4], bin_block[4:8], bin_block[8:12]).map(bin2int), bin_block[12:-4], bin_block[-4:])

# %%
# %%time
compressed = parse_bin(arquivos[2])
# Out:
# Wall time: 11.1 s

# %%
multi.keys()
# Out:
# dict_keys(['file_version', 'string', 'blocks'])

# %%
multi['file_version']
# Out:
# 22

# %%
multi['string']
# Out:
# 'CRFS DATA FILE V022'

# %%
b = multi['blocks']

# %%
c = compressed['blocks']

# %%
# %%time
meta = extract_metadata(compressed)
# Out:
# Wall time: 1min 50s

# %%
meta[(68,301)]
# Out:
#                            start_byte  stop_byte antenna_id  bw data_size  \
# wallclock_datetime
# 2021-02-23T16:31:39.184353       1584       2071          0  29       472
# 2021-02-23T16:31:49.404336       2076       2787          0  29       696
# 2021-02-23T16:31:55.754327       3040       3703          0  29       648
# 2021-02-23T16:32:01.794339       3768       4391          0  29       608
# 2021-02-23T16:32:07.774330       4396       5179          0  29       768
# ...                               ...        ...        ...  ..       ...
# 2021-03-08T12:12:41.276566   99997468   99998071          0  29       588
# 2021-03-08T12:12:46.316587   99998076   99998723          0  29       632
# 2021-03-08T12:12:51.356580   99998728   99999379          0  29       636
# 2021-03-08T12:12:56.446654   99999384   99999967          0  29       568
# 2021-03-08T12:13:01.456950  100000032  100000731          0  29       684
#
#                            data_type desclen  \
# wallclock_datetime
# 2021-02-23T16:31:39.184353         0      44
# 2021-02-23T16:31:49.404336         0      44
# 2021-02-23T16:31:55.754327         0      44
# 2021-02-23T16:32:01.794339         0      44
# 2021-02-23T16:32:07.774330         0      44
# ...                              ...     ...
# 2021-03-08T12:12:41.276566         0      44
# 2021-03-08T12:12:46.316587         0      44
# 2021-03-08T12:12:51.356580         0      44
# 2021-03-08T12:12:56.446654         0      44
# 2021-03-08T12:13:01.456950         0      44
#
#                                                             description  \
# wallclock_datetime
# 2021-02-23T16:31:39.184353  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# 2021-02-23T16:31:49.404336  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# 2021-02-23T16:31:55.754327  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# 2021-02-23T16:32:01.794339  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# 2021-02-23T16:32:07.774330  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# ...                                                                 ...
# 2021-03-08T12:12:41.276566  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# 2021-03-08T12:12:46.316587  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# 2021-03-08T12:12:51.356580  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# 2021-03-08T12:12:56.446654  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
# 2021-03-08T12:13:01.456950  PMEC 2021 (Faixa 1 de 10). @ -80dBm, 10kHz.
#
#                            dynamic_id gerror  ... start_mili  \
# wallclock_datetime                            ...
# 2021-02-23T16:31:39.184353          0     -1  ...          0
# 2021-02-23T16:31:49.404336          0     -1  ...          0
# 2021-02-23T16:31:55.754327          0     -1  ...          0
# 2021-02-23T16:32:01.794339          0     -1  ...          0
# 2021-02-23T16:32:07.774330          0     -1  ...          0
# ...                               ...    ...  ...        ...
# 2021-03-08T12:12:41.276566          0     -1  ...          0
# 2021-03-08T12:12:46.316587          0     -1  ...          0
# 2021-03-08T12:12:51.356580          0     -1  ...          0
# 2021-03-08T12:12:56.446654          0     -1  ...          0
# 2021-03-08T12:13:01.456950          0     -1  ...          0
#
#                                             step stop stop_channel stop_mega  \
# wallclock_datetime
# 2021-02-23T16:31:39.184353   0.15343915343915343  470            0       137
# 2021-02-23T16:31:49.404336   0.07004830917874397  695            0       137
# 2021-02-23T16:31:55.754327   0.07945205479452055  646            0       137
# 2021-02-23T16:32:01.794339   0.08950617283950617  605            0       137
# 2021-02-23T16:32:07.774330  0.059670781893004114  767            0       137
# ...                                          ...  ...          ...       ...
# 2021-03-08T12:12:41.276566   0.09477124183006536  587            0       137
# 2021-03-08T12:12:46.316587    0.0830945558739255  630            0       137
# 2021-03-08T12:12:51.356580   0.08169014084507042  636            0       137
# 2021-03-08T12:12:56.446654   0.10139860139860139  567            0       137
# 2021-03-08T12:13:01.456950   0.07196029776674938  684            0       137
#
#                            stop_mili thread_id thresh type file_version
# wallclock_datetime
# 2021-02-23T16:31:39.184353         0       301   -100   68           23
# 2021-02-23T16:31:49.404336         0       301   -100   68           23
# 2021-02-23T16:31:55.754327         0       301   -100   68           23
# 2021-02-23T16:32:01.794339         0       301   -100   68           23
# 2021-02-23T16:32:07.774330         0       301   -100   68           23
# ...                              ...       ...    ...  ...          ...
# 2021-03-08T12:12:41.276566         0       301   -100   68           23
# 2021-03-08T12:12:46.316587         0       301   -100   68           23
# 2021-03-08T12:12:51.356580         0       301   -100   68           23
# 2021-03-08T12:12:56.446654         0       301   -100   68           23
# 2021-03-08T12:13:01.456950         0       301   -100   68           23
#
# [133932 rows x 36 columns]
